# %% [markdown]
# ## MAIN PROGRAM FILE

# %% [markdown]
# ### Import dependencies

# %%
import pandas as pd
import os
from config import gkey
import gmaps
from scipy.stats import linregress
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np
import requests
from pprint import pprint
import json

# %% [markdown]
# #### Calling the CSV files and combining the data on both CSVs for State = Delaware

# %%
###CALLLING OUT CSV FILE LOCATIONS
csv_path_1 = os.path.join ("..","Resources","Census_Data_2015.csv")
csv_path_2 = os.path.join("..", "Resources","Tract_lat_lon.csv")

### READING CSV DATA INTO DATA FRAMES
Maindata_1_df = pd.read_csv(csv_path_1)
lat_lon_tract_df = pd.read_csv(csv_path_2)

###CHECKING DATA FRAME HEADS TO ENSURE DATA IS BEING CORRECTLY READ
Maindata_1_df.head()
lat_lon_tract_df.head()

###MERGING TWO DATA FRAMES TO GET FINAL DATAFRAME WITH CENSUS AND GEOGROPHIC INFO COMBINED
# THE INNER MERGE WILL ONLY SHOW THOSE ROWS THAT HAVE INFO IN BOTH CSV FILES. IN DOING THIS WE LOST DATA OF 25 TRACT WHICH DID NOT HAVE LAT LONGS

Combined_df = pd.merge(Maindata_1_df, lat_lon_tract_df, on='CENSUSTRACT', how = 'inner')

###CHECKING DATA FRAME SHAPE TO SEE HOW MANY ROWS AND COLUMNS ARE THERE. 
###THIS HV_final_df IS THE DATA FRAME THAT CAN BE USED BY ALL TEAM MEMBERS FOR THEIR INDIVIDUAL PROCESSING


###OUTPUT THE FINAL DATA FRAME WITH LAT LON + CENSUS DATA INTO CSV FILE IN OUTPUT FOLDER
###HV_final_df.to_csv(os.path.join("..","Output", "Census_data_and_lat_lon.csv"), encoding = "utf-8", index = False)
Combined_df.head()

## DATA FRAME FOR ALL DATA FOR A SINGLE STATE TO REDUCE COMPUTATIONAL TIME FOR ETL PROJECT##
## SELECTED BELOW IS DATA FOR DELAWARE  ##


Combined_State_df = Combined_df[Combined_df ["State"] == 'Delaware']
Combined_State_df.head()
# Out:
#        CENSUSTRACT     State County  Urban  POP2010  OHU2010  \
# 13674  10001040100  Delaware   Kent      0     6541     2325
# 13675  10001040201  Delaware   Kent      0     5041     1849
# 13676  10001040202  Delaware   Kent      1    12763     4451
# 13677  10001040203  Delaware   Kent      0     5017     1877
# 13678  10001040501  Delaware   Kent      1     4923     1910
#
#        GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 13674                  0         0  0.000000                  0  ...
# 13675                  0         2  0.000397                  0  ...
# 13676                  0       340  0.026639                  0  ...
# 13677                  0         0  0.000000                  0  ...
# 13678                  0         0  0.000000                  0  ...
#
#        TractOMultir  TractHispanic  TractHUNV  TractSNAP        ALAND  \
# 13674           183            247         39        418  124745855.0
# 13675           290            312        160        322    9730214.0
# 13676           568            593        121        249   31927916.0
# 13677           269            261        146        289   59860927.0
# 13678           392            413        142        345   10394085.0
#
#         AWATER  ALAND_SQMI  AWATER_SQMI        LAT        LON
# 13674        0      48.165        0.000  39.237284 -75.694741
# 13675    37235       3.757        0.014  39.290841 -75.637508
# 13676   700605      12.327        0.271  39.263964 -75.611123
# 13677  1054612      23.112        0.407  39.285868 -75.550836
# 13678        0       4.013        0.000  39.199584 -75.543902
#
# [5 rows x 154 columns]

# %% [markdown]
# #### Copied the tables to a new table with the columns we need

# %%
sv_new_Combined_State_df = Combined_State_df[['CENSUSTRACT', 'State', 'County', 'POP2010', 'OHU2010', 'MedianFamilyIncome', 'TractHUNV', 'PovertyRate', 'LAT', 'LON']].copy()
sv_new_Combined_State_df.head()
# Out:
#        CENSUSTRACT     State County  POP2010  OHU2010  MedianFamilyIncome  \
# 13674  10001040100  Delaware   Kent     6541     2325               71188
# 13675  10001040201  Delaware   Kent     5041     1849               54826
# 13676  10001040202  Delaware   Kent    12763     4451               73155
# 13677  10001040203  Delaware   Kent     5017     1877               69273
# 13678  10001040501  Delaware   Kent     4923     1910               57891
#
#        TractHUNV  PovertyRate        LAT        LON
# 13674         39         10.7  39.237284 -75.694741
# 13675        160          8.7  39.290841 -75.637508
# 13676        121          5.3  39.263964 -75.611123
# 13677        146         11.9  39.285868 -75.550836
# 13678        142         16.9  39.199584 -75.543902

# %% [markdown]
# #### Rename the columns

# %%
columns_rename = ['Census_tract', 'State', 'County', 'Total_Population', 'Total_Housing_Units', 'Median_Family_Income', 'Units_Without_Vehicle', 'Poverty_Rate',  'Latitude', 'Longitude' ]

# %%
sv_new_Combined_State_df.columns=columns_rename

# %%
sv_new_Combined_State_df.head()
# Out:
#        Census_tract     State County  Total_Population  Total_Housing_Units  \
# 13674   10001040100  Delaware   Kent              6541                 2325
# 13675   10001040201  Delaware   Kent              5041                 1849
# 13676   10001040202  Delaware   Kent             12763                 4451
# 13677   10001040203  Delaware   Kent              5017                 1877
# 13678   10001040501  Delaware   Kent              4923                 1910
#
#        Median_Family_Income  Units_Without_Vehicle  Poverty_Rate   Latitude  \
# 13674                 71188                     39          10.7  39.237284
# 13675                 54826                    160           8.7  39.290841
# 13676                 73155                    121           5.3  39.263964
# 13677                 69273                    146          11.9  39.285868
# 13678                 57891                    142          16.9  39.199584
#
#        Longitude
# 13674 -75.694741
# 13675 -75.637508
# 13676 -75.611123
# 13677 -75.550836
# 13678 -75.543902

# %% [markdown]
# #### Calling on google places API for getting car dealer information and combining the date received with the above table

# %%
params = {
    "radius": 50000,
    "types": "car_dealer",
    "key": gkey
}

# USING LAT AND LON FROM THE STATE DATA FRAME ABOVE#
for index, row in sv_new_Combined_State_df.iterrows():
    
    # GET LAT & LON FROM COMBINED_TEXAS_DF
    lat = row["Latitude"]
    lng = row["Longitude"]
   
    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# make request and print url
dealers_info = requests.get(base_url, params=params)


    # convert to json
dealersinfo_response = dealers_info.json()

  
pprint(dealersinfo_response)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CtQCRgEAADx9Wd07WJ-_19InMiXWQRZ4UmV6UAxgb6RA0udhgdBA_Db_bJ7j9M-QyFuxeF3Z_Dijjujhh7in2Gbl6RLTOMHXWDLSEQNWi42zK61wUmQDsEB--qY7UeJuhMWfY6aBNY1nRs2y7x2ZIguJ7v1c6VJFVlaOvM3mfs9LVJZHMCpTKEj4r2iX8ICVhLFCqKKPw9lt3kl5Gi1DOs6mTFBB1hzXAV8gNGzg1utIFpOZsAB5NxKPGOu1t1I3kzfKoPn8L5_3GIaEIn6Gw3uZBJ9N6blxG69mKk6CvB1-CeamBhNjPWbFq-mjy5A2QVePpKzZtVRGZE26RLqoMQU_qHX8RD6sIZM2XcX6xdNsyejcOCU_ZvQ84TsbK9UMxuJ_ewDx35B8nSd0XgR2f_EsUssgmrP5C-6__YKh934Ri6CtejedtPIU96IgGDkZXEK0vO_1vRIQIcniymwdupjUZU5sSeWO-xoUiovQ4C98EMAuTbv9V0CciK79gq8',
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 39.1526773, 'lng': -75.5128244},
#                            'viewport': {'northeast': {'lat': 39.1539336302915,
#                                                       'lng': -75.5115231697085},
#                                         'southwest': {'lat': 39.15123566970851,
#                                                       'lng': -75.5142211302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'name': 'Winner Ford',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3287,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107857434438528867640">Winner '
#                                                 'Ford</a>'],
#                           'photo_reference': 'CmRaAAAAf2qcJn_irYY9P5jurBdhowk2_3BoMnveha2wRiyqElhIOR5RCY-J_Cc9izvlJEteKwCeAJNfOXmdWDf81Z_IQO1nh3ZsjsMRDjy8vzbU1XfC1TgdYrR_iFlJUg3TQwyUEhCtUQ992rjcMBDfdVzrstQ1GhRCDgspAH-XdtGZtVJssM9VK63TlQ',
#                           'width': 6305}],
#               'place_id': 'ChIJ4fiZXFhjx4kROsnau2TiBe0',
#               'plus_code': {'compound_code': '5F3P+3V Dover, DE, USA',
#                             'global_code': '87F65F3P+3V'},
#               'rating': 4.3,
#               'reference': 'ChIJ4fiZXFhjx4kROsnau2TiBe0',
#               'scope': 'GOOGLE',
#               'types': ['car_dealer',
#                         'car_repair',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 692,
#               'vicinity': '591 South Dupont Highway, Dover'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 38.6703147, 'lng': -75.3860473},
#                            'viewport': {'northeast': {'lat': 38.67171373029149,
#                                                       'lng': -75.38460206970849},
#                                         'southwest': {'lat': 38.6690157697085,
#                                                       'lng': -75.3873000302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'name': 'First State Chevrolet',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1152,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/111688524030342291954">First '
#                                                 'State Chevrolet</a>'],
#                           'photo_reference': 'CmRaAAAA5PF4GGK4cHZxrJT7ZvrW_A4CwLMH--BMpbNncqH68RWPXyRrRhw7ssxE-oVzSdnaMbkIxZnFQk2n0aZHlCrll_oLX3zjxzVdIpa-FgGioPOV35o2_HRtPL-J1Ysq85p9EhAzCxdvWaNW7nVvGMxiqUVAGhQ9ziyB-0Lg5r-pBkYPjXG_7gJoNQ',
#                           'width': 2048}],
#               'place_id': 'ChIJa7l4BEvquIkRjK9NicYWyxw',
#               'plus_code': {'compound_code': 'MJC7+4H Georgetown, DE, USA',
#                             'global_code': '87C6MJC7+4H'},
#               'rating': 4.1,
#               'reference': 'ChIJa7l4BEvquIkRjK9NicYWyxw',
#               'scope': 'GOOGLE',
#               'types': ['car_dealer',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 189,
#               'vicinity': '22694 Dupont Boulevard, Georgetown'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 39.1446869,
#                                         'lng': -75.51631189999999},
#                            'viewport': {'northeast': {'lat': 39.1459140802915,
#                                                       'lng': -75.51507786970849},
#                                         'southwest': {'lat': 39.1432161197085,
#                                                       'lng': -75.5177758302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'name': 'Car Zone',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1152,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110744935793884737538">Car '
#                                                 'Zone</a>'],
#                           'photo_reference': 'CmRaAAAATJT4Th0f_1WB7c3_GqfWhFaU0lDFeIaPbkpqW0CUkaa0FzAflVMX1Vgvh7s7Y_fhWz2muu4-4M3XmCURTL7jHYRrX234QQ_Et07cdhUqMWqHTNQgEPxeV54-wMgKx88oEhA9DFcICCruxah2SaYDujlbGhSh-zegGTxb4I6fGKa_i1vc9-mS_g',
#                           'width': 2048}],
#               'place_id': 'ChIJXyseA1Bjx4kRcBHcKkLLSxY',
#               'plus_code': {'compound_code': '4FVM+VF Dover, DE, USA',
#                             'global_code': '87F64FVM+VF'},
#               'rating': 4,
#               'reference': 'ChIJXyseA1Bjx4kRcBHcKkLLSxY',
#               'scope': 'GOOGLE',
#               'types': ['car_dealer',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 147,
#               'vicinity': '1041 South Dupont Highway, Dover'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 38.74919560000001,
#                                         'lng': -75.1622332},
#                            'viewport': {'northeast': {'lat': 38.7505182302915,
#                                                       'lng': -75.1609510697085},
#                                         'southwest': {'lat': 38.74782026970851,
#                                                       'lng': -75.16364903029151}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'name': 'i.g. Burton Lewes Automall',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 896,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100514938584034807602">i.g. '
#                                                 'Burton Lewes Automall</a>'],
#                           'photo_reference': 'CmRaAAAAHT6KPb6oHm6k6I9cLzbB1TikxTSa0ReE3cK8RGY519fg4kGCU3Tl9Y6RO538F29APqeAvO8Loj3cgP26j-vWnPXpNlyN4AXBjMnLWvegitOh_naV_gg9OHV2w0X9RYTNEhAdWOriCN8sZE-NykKhd46hGhRpACf0lIk4q01ONGzAbVNzwOhkow',
#                           'width': 1594}],
#               'place_id': 'ChIJTV_a49C5uIkRJoxkJpMY1T8',
#               'plus_code': {'compound_code': 'PRXQ+M4 Lewes, DE, USA',
#                             'global_code': '87C6PRXQ+M4'},
#               'rating': 4.3,
#               'reference': 'ChIJTV_a49C5uIkRJoxkJpMY1T8',
#               'scope': 'GOOGLE',
#               'types': ['car_dealer',
#                         'car_repair',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 265,
#               'vicinity': '17861 Coastal Highway, Lewes'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 38.9586532, 'lng': -75.430238},
#                            'viewport': {'northeast': {'lat': 38.9599751802915,
#                                                       'lng': -75.4288768197085},
#                                         'southwest': {'lat': 38.9572772197085,
#                                                       'lng': -75.43157478029151}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'name': 'Hertrich Toyota of Milford',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1292,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113380622027084126805">Hertrich '
#                                                 'Toyota of Milford</a>'],
#                           'photo_reference': 'CmRaAAAA9WJrihCKHmi5O6lpIj6HmfTSrlHgiUbgaS1_YvbqH89JnGgegLrZDXcG01TH2on4Dhz50HmkIo_8C_HKIxfM5A1494ojam8G4QbuwlJRA6koq1tdiZ5rehmzfocnocPoEhCbxE3wdB14OVWweC0fR-3SGhRPvV_JJW1B0GeVSsp1RSYh2-_rKA',
#                           'width': 3036}],
#               'place_id': 'ChIJo8KkSmeZuIkRsyNeS3BIQIg',
#               'plus_code': {'compound_code': 'XH59+FW Milford, DE, USA',
#                             'global_code': '87C6XH59+FW'},
#               'rating': 4.7,
#               'reference': 'ChIJo8KkSmeZuIkRsyNeS3BIQIg',
#               'scope': 'GOOGLE',
#               'types': ['car_dealer',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 1053,
#               'vicinity': '1367 Bay Road, Milford'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 38.95067710000001,
#                                         'lng': -75.42716949999999},
#                            'viewport': {'northeast': {'lat': 38.9520873302915,
#                                                       'lng': -75.42581916970849},
#                                         'southwest': {'lat': 38.9493893697085,
#                                                       'lng': -75.4285171302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'name': 'i.g. Burton Chevrolet of Milford',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 315,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117404795866936673674">i.g. '
#                                                 'Burton Chevrolet of '
#                                                 'Milford</a>'],
#                           'photo_reference': 'CmRaAAAAGbtvJqo8f0Rcc7vhzadAh3IG4WpugrjHUnrwq18na74ESC_iw6tRTIr4C6KdA1oBlc5KpEhgSWfcW3LBuSQSY0cDz4cARyBF9TmdHOw1_TgAKGJtO6KyB5hC5QYBfTC5EhBxVrxQPdrnj_pTp93KHjpQGhQaPWtRj0Weh5KBsvdXGMTXu_hujQ',
#                           'width': 851}],
#               'place_id': 'ChIJfSNiu3uZuIkRn9OASe1yj88',
#               'plus_code': {'compound_code': 'XH2F+74 Milford, DE, USA',
#                             'global_code': '87C6XH2F+74'},
#               'rating': 4.3,
#               'reference': 'ChIJfSNiu3uZuIkRn9OASe1yj88',
#               'scope': 'GOOGLE',
#               'types': ['car_dealer',
#                         'car_repair',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 235,
#               'vicinity': '793 Bay Road, Milford'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 38.98148920000001,
#                                         'lng': -75.5661657},
#                            'viewport': {'northeast': {'lat': 38.9828357802915,
#                                                       'lng': -75.5649241197085},
#                                         'southwest': {'lat': 38.9801378197085,
#                                                       'lng': -75.5676220802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'name': 'Felton Holly Kia',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 720,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109329055484872986790">Felton '
#                                                 'Holly Kia</a>'],
#                           'photo_reference': 'CmRaAAAAVODL-aJ_KGfzX6aXuGSO_FrfyhKX9xjSs-yn6lfAY_UiFkKjnsZsZezx7CjnkZUVe2WFMbf_gn-UZJOnH_nK1CM1HuVGyomu_hMh3ZwxpzJilw_CqycNmKR_0XnGw8crEhAvQvqakep3g04itwsdeMrjGhREcYnx-haVLNll4IrsRphMq8fVRA',
#                           'width': 1080}],
#               'place_id': 'ChIJ0QDYjfOEuIkR7rjQbe0I518',
#               'plus_code': {'compound_code': 'XCJM+HG Felton, DE, USA',
#                             'global_code': '87C6XCJM+HG'},
#               'rating': 4.1,
#               'reference': 'ChIJ0QDYjfOEuIkR7rjQbe0I518',
#               'scope': 'GOOGLE',
#               'types': ['finance',
#                         'car_dealer',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 272,
#               'vicinity': '13173 South Dupont Highway, Felton'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 39.100501, 'lng': -75.542461},
#                            'viewport': {'northeast': {'lat': 39.10193848029149,
#                                                       'lng': -75.54143716970849},
#                                         'southwest': {'lat': 39.09924051970849,
#                                                       'lng': -75.5441351302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'name': 'Price Honda Dover',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1536,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113152252034759145026">Price '
#                                                 'Honda Dover</a>'],
#                           'photo_reference': 'CmRaAAAA6ln6WdO7Bmon8L_wXmPNQW5E_EwT99ly8_k_XIXizz5oYPadTCHB1DKI7FWvtdoYoIPLvFMvPZekhjEi4OAzMR6vJ1eMdbsM9od7sCe3IdkLQQVW2-F5hv7WNaKrLJY4EhABYHxfWRnQ4BKfUI6bqZDLGhQSfHmvJ_GjQdV8tLH_kVfNjp830w',
#                           'width': 2048}],
#               'place_id': 'ChIJR9BfyUB9x4kRo8l_7volppI',
#               'plus_code': {'compound_code': '4F25+62 Dover, DE, USA',
#                             'global_code': '87F64F25+62'},
#               'rating': 4.6,
#               'reference': 'ChIJR9BfyUB9x4kRo8l_7volppI',
#               'scope': 'GOOGLE',
#               'types': ['finance',
#                         'car_dealer',
#                         'car_repair',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 882,
#               'vicinity': '4567 South Dupont Highway, Dover'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 38.94632420000001,
#                                         'lng': -75.4270686},
#                            'viewport': {'northeast': {'lat': 38.94781878029151,
#                                                       'lng': -75.4255014697085},
#                                         'southwest': {'lat': 38.94512081970851,
#                                                       'lng': -75.42819943029151}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'name': 'i.g. Burton BMW of Milford',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 996,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/104701126452070630890">i.g. '
#                                                 'Burton BMW of Milford</a>'],
#                           'photo_reference': 'CmRaAAAANijKyVgX60oz4sX0CWyljoWeByr7GPn09NE35qcIJPZsyso2tGzR7JmTI9RR2Ed2m_z4SYMaSdWwta9DlXbsAzNTLLO3Xflb72fkjtkogWIcH_ipy4epOB1ELX5bBVIGEhCAK8rY0PEyqm2HhPWLuLd-GhQYRbszHvtqg8-kpv217eKfqg9Wmw',
#                           'width': 1500}],
#               'place_id': 'ChIJX1BTo3uZuIkRqd8WAeJLZZM',
#               'plus_code': {'compound_code': 'WHWF+G5 Milford, DE, USA',
#                             'global_code': '87C6WHWF+G5'},
#               'rating': 4.4,
#               'reference': 'ChIJX1BTo3uZuIkRqd8WAeJLZZM',
#               'scope': 'GOOGLE',
#               'types': ['car_dealer',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 293,
#               'vicinity': '509 Bay Road, Milford'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 38.9593222, 'lng': -75.4301388},
#                            'viewport': {'northeast': {'lat': 38.96067118029149,
#                                                       'lng': -75.42878981970848},
#                                         'southwest': {'lat': 38.95797321970849,
#                                                       'lng': -75.4314877802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'name': 'Hertrich Ford Lincoln',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 280,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108379433544036993737">Hertrich '
#                                                 'Ford Lincoln</a>'],
#                           'photo_reference': 'CmRaAAAAE0SbOOSB-8Obc2_-7Mjd6ZofTO2lR_8lhn2lOpdTnBc1HTnBZ0anDw-Z4jN4fkyEpQkfe-nu7WD7ZWOTcWf_bJxiJ7-gGk384fAI-8dEeeDxS7pzOpp4yuUkDOI5RVtDEhDebwlRUSFWkoPha6drZ8wBGhQ3MinKfor3wxL7JXMgJokDE68d6w',
#                           'width': 745}],
#               'place_id': 'ChIJEym1n2CZuIkRPaEEfjE5byI',
#               'plus_code': {'compound_code': 'XH59+PW Milford, DE, USA',
#                             'global_code': '87C6XH59+PW'},
#               'rating': 4.1,
#               'reference': 'ChIJEym1n2CZuIkRPaEEfjE5byI',
#               'scope': 'GOOGLE',
#               'types': ['car_dealer',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 187,
#               'vicinity': '1427 Bay Road, Milford'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 38.607988, 'lng': -75.5841614},
#                            'viewport': {'northeast': {'lat': 38.60935583029149,
#                                                       'lng': -75.58282271970849},
#                                         'southwest': {'lat': 38.60665786970849,
#                                                       'lng': -75.5855206802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'name': 'Frederick Ford',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1090,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108963127911793122623">Frederick '
#                                                 'Ford</a>'],
#                           'photo_reference': 'CmRaAAAAyfn7RjLDYYGZINZZg8CTSPJy24YBy-6pD2_R9p1nVGrpisPAPfmDjjehHarm_zc-MhBanl8HhGNdfWrAEr_TknDPm4zAn4eS3nPXsp_BJkn80PJsg2J22AZ7EfrszMF4EhD5etf0DfBTPn7S4P37RtY-GhShblyxuqf6URNdTijoGCVQCl6SyA',
#                           'width': 2048}],
#               'place_id': 'ChIJb5TR-xTxuIkRcQCmeUeN_bg',
#               'plus_code': {'compound_code': 'JC58+58 Seaford, DE, USA',
#                             'global_code': '87C6JC58+58'},
#               'rating': 4.3,
#               'reference': 'ChIJb5TR-xTxuIkRcQCmeUeN_bg',
#               'scope': 'GOOGLE',
#               'types': ['car_dealer',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 246,
#               'vicinity': '26905 Sussex Highway, Seaford'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 39.09553199999999,
#                                         'lng': -75.545042},
#                            'viewport': {'northeast': {'lat': 39.09691983029149,
#                                                       'lng': -75.54379446970849},
#                                         'southwest': {'lat': 39.09422186970849,
#                                                       'lng': -75.5464924302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'name': 'Diamond Motor Sports Inc',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1536,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102242398578365625030">Kat '
#                                                 'Furta</a>'],
#                           'photo_reference': 'CmRaAAAAEIE0LXv38rxazDwzIER08L9_VLMWzvkQDRBZb7V0FtdTp4Uo2cOfTVrd9DYXZFpILGMjjAplciLltQGKE_ZuNCRjCDhj6xP2dsIyJ4QroeTMiLc3lwYKH7nwA1T-RPJXEhAOBNPgOf2nUCBtzyCog-MvGhSzAg72Wk5tzjIu6tcHsXIyyZ1_Kg',
#                           'width': 2048}],
#               'place_id': 'ChIJz6OUzkB9x4kRp0Z6bJTfMM8',
#               'plus_code': {'compound_code': '3FW3+6X Dover, DE, USA',
#                             'global_code': '87F63FW3+6X'},
#               'rating': 4.4,
#               'reference': 'ChIJz6OUzkB9x4kRp0Z6bJTfMM8',
#               'scope': 'GOOGLE',
#               'types': ['insurance_agency',
#                         'car_dealer',
#                         'car_repair',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 302,
#               'vicinity': '4595 South Dupont Highway, Dover'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 38.9239981, 'lng': -75.425907},
#                            'viewport': {'northeast': {'lat': 38.9254493302915,
#                                                       'lng': -75.42441031970849},
#                                         'southwest': {'lat': 38.9227513697085,
#                                                       'lng': -75.4271082802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'name': 'R Addington Inc.',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2988,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100411476317297335912">Francisco '
#                                                 'Chávez</a>'],
#                           'photo_reference': 'CmRaAAAA2ixbPAtYnCPOjrVsDHfQr6aRqC_F94sNsdJNa9vS-m7b2uHI1Ch_xnX_toM4WdBeeWGV8Zc5jl89kcuffThLWz5Ii6Y_G1SNk3igblJsqymfdit8jMjyUnwhenA_Rx_dEhB3XGTfWHm0GctMbj5Mok_KGhRXOQXtS4YvaWPsywzWudZx3NU8mg',
#                           'width': 5312}],
#               'place_id': 'ChIJradfho6ZuIkRyz7rrcx_Wh0',
#               'plus_code': {'compound_code': 'WHFF+HJ Milford, DE, USA',
#                             'global_code': '87C6WHFF+HJ'},
#               'rating': 4,
#               'reference': 'ChIJradfho6ZuIkRyz7rrcx_Wh0',
#               'scope': 'GOOGLE',
#               'types': ['car_dealer',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 45,
#               'vicinity': '316 North Rehoboth Boulevard, Milford'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 38.9479473, 'lng': -75.4266775},
#                            'viewport': {'northeast': {'lat': 38.9492771302915,
#                                                       'lng': -75.4251426197085},
#                                         'southwest': {'lat': 38.9465791697085,
#                                                       'lng': -75.4278405802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'name': 'i.g. Burton Chrysler Dodge Jeep Ram Fiat',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 960,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113125967864595892187">i.g. '
#                                                 'Burton Chrysler Dodge Jeep '
#                                                 'Ram Fiat</a>'],
#                           'photo_reference': 'CmRaAAAAVcErRDvXpFcJF9ohqRWd7jmOvmc1jxYOVZo37-n-GHUbCSetn2yd-RNn-SPMPTHrD7JdtkPYtM4iYiahts5gGWuDpYMW60776bY5qQeHPiOJfxk3cX5eHkxm-XCbLUSKEhDfNuFvrupiKt7AIYXrOTj9GhRy6wQSn5QDFB_UtHi2Ljr9CKtUtg',
#                           'width': 960}],
#               'place_id': 'ChIJv0mGInuZuIkRoxIXx5NEG8M',
#               'plus_code': {'compound_code': 'WHXF+58 Milford, DE, USA',
#                             'global_code': '87C6WHXF+58'},
#               'rating': 4.3,
#               'reference': 'ChIJv0mGInuZuIkRoxIXx5NEG8M',
#               'scope': 'GOOGLE',
#               'types': ['car_dealer',
#                         'car_repair',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 244,
#               'vicinity': '605 Bay Road, Milford'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 39.0352833, 'lng': -74.9325594},
#                            'viewport': {'northeast': {'lat': 39.0366840302915,
#                                                       'lng': -74.93130161970849},
#                                         'southwest': {'lat': 39.0339860697085,
#                                                       'lng': -74.93399958029151}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'name': 'R & H Auto Sales',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1536,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117153275928504746007">R '
#                                                 '&amp; H Auto Sales</a>'],
#                           'photo_reference': 'CmRaAAAAdFEYRXLbZRntyMhor1hIAcHs5wtEsWpn8wWgbna1v0uuP44SIumLKAF7gks9aC_YopR5es1dm7h34UTVgPy4KU18hIMye6YrRXmYqZk4_GjybCfeRzs1NC_3c2C5XVcSEhAascCnMip8tSmvraPyjqGgGhSdm7VZKDGEfABZRBxeSg9u8pa-hw',
#                           'width': 2048}],
#               'place_id': 'ChIJY_Ef0_yqwIkROGVqhRnx9EA',
#               'plus_code': {'compound_code': '23P8+4X Villas, NJ, USA',
#                             'global_code': '87F723P8+4X'},
#               'rating': 4.6,
#               'reference': 'ChIJY_Ef0_yqwIkROGVqhRnx9EA',
#               'scope': 'GOOGLE',
#               'types': ['car_dealer',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 71,
#               'vicinity': '300 Bayshore Road, Villas'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 38.725749, 'lng': -75.589976},
#                            'viewport': {'northeast': {'lat': 38.7270800302915,
#                                                       'lng': -75.58890371970848},
#                                         'southwest': {'lat': 38.7243820697085,
#                                                       'lng': -75.5916016802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'name': "Gene's Auto Sales",
#               'opening_hours': {'open_now': True},
#               'place_id': 'ChIJX6Ub8g7zuIkRIHYE-Mzrff4',
#               'plus_code': {'compound_code': 'PCG6+72 Bridgeville, DE, USA',
#                             'global_code': '87C6PCG6+72'},
#               'rating': 2.7,
#               'reference': 'ChIJX6Ub8g7zuIkRIHYE-Mzrff4',
#               'scope': 'GOOGLE',
#               'types': ['car_dealer',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 10,
#               'vicinity': '18583 Sussex Highway, Bridgeville'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 38.765003, 'lng': -75.2115776},
#                            'viewport': {'northeast': {'lat': 38.7664252802915,
#                                                       'lng': -75.21014781970851},
#                                         'southwest': {'lat': 38.7637273197085,
#                                                       'lng': -75.21284578029152}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'name': '50StateAutoloan LLC',
#               'opening_hours': {'open_now': False},
#               'place_id': 'ChIJ9UeSss65uIkRpYEFlb5dYBI',
#               'plus_code': {'compound_code': 'QQ8Q+29 Lewes, DE, USA',
#                             'global_code': '87C6QQ8Q+29'},
#               'reference': 'ChIJ9UeSss65uIkRpYEFlb5dYBI',
#               'scope': 'GOOGLE',
#               'types': ['finance',
#                         'car_dealer',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'vicinity': '16192 Coastal Highway, Lewes'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 38.7101929,
#                                         'lng': -75.09419319999999},
#                            'viewport': {'northeast': {'lat': 38.71164853029151,
#                                                       'lng': -75.0928293197085},
#                                         'southwest': {'lat': 38.70895056970851,
#                                                       'lng': -75.0955272802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'name': 'All Scoots',
#               'opening_hours': {'open_now': True},
#               'place_id': 'ChIJWaYPDTm2uIkR0gxMvZgkhq0',
#               'plus_code': {'compound_code': 'PW64+38 Rehoboth Beach, DE, USA',
#                             'global_code': '87C6PW64+38'},
#               'rating': 4.4,
#               'reference': 'ChIJWaYPDTm2uIkR0gxMvZgkhq0',
#               'scope': 'GOOGLE',
#               'types': ['car_dealer',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 5,
#               'vicinity': '37522 Oyster House Road, Rehoboth Beach'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 38.6668675, 'lng': -75.1700248},
#                            'viewport': {'northeast': {'lat': 38.6681980802915,
#                                                       'lng': -75.16871191970849},
#                                         'southwest': {'lat': 38.6655001197085,
#                                                       'lng': -75.1714098802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'name': 'Nationwide Auto Whls Inc',
#               'place_id': 'ChIJJb0A7c7HuIkRss6XWeLehmE',
#               'rating': 4,
#               'reference': 'ChIJJb0A7c7HuIkRss6XWeLehmE',
#               'scope': 'GOOGLE',
#               'types': ['car_dealer',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': '23417 Dogwood Court, Lewes'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 38.9720432, 'lng': -75.4344213},
#                            'viewport': {'northeast': {'lat': 38.9733428802915,
#                                                       'lng': -75.4332448697085},
#                                         'southwest': {'lat': 38.9706449197085,
#                                                       'lng': -75.43594283029151}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'name': 'Studio 8 Used Cars',
#               'place_id': 'ChIJ4xx-3leZuIkRA0RnIn0Y2-s',
#               'plus_code': {'compound_code': 'XHC8+R6 Milford, DE, USA',
#                             'global_code': '87C6XHC8+R6'},
#               'rating': 4,
#               'reference': 'ChIJ4xx-3leZuIkRA0RnIn0Y2-s',
#               'scope': 'GOOGLE',
#               'types': ['car_dealer',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 2,
#               'vicinity': '2358 Bay Road, Milford'}],
#  'status': 'OK'}

# %%
## GOOGLE PLACES API CALL OUT FOR GETTING DEALER INFO

car_dealers = []

# PARAMS DICT TO UPDATE ALONG EACH ROW
params = {
    "radius": 50000,
    "types": "car_dealer",
    "key": gkey
}

# USING LAT AND LON FROM THE STATE DATA FRAME ABOVE#
for index, row in sv_new_Combined_State_df.iterrows():
    
    # GET LAT & LON FROM COMBINED_TEXAS_DF
    lat = row["Latitude"]
    lng = row["Longitude"]
   
    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"

    # Use the search term: "Delaware" and our lat/lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # make request and print url
    dealers_info = requests.get(base_url, params=params)


    # convert to json
    dealers_response = dealers_info.json()
  
    try:
        car_dealers.append(dealers_response["results"][1]["name"])
    except:
        car_dealers.append("Car dealer not found")

# Dataframe with nearest car dealer
sv_new_Combined_State_df["Car Dealer"] = car_dealers
sv_new_Combined_State_df.head(100)
# Out:
#        Census_tract     State      County  Total_Population  \
# 13674   10001040100  Delaware        Kent              6541
# 13675   10001040201  Delaware        Kent              5041
# 13676   10001040202  Delaware        Kent             12763
# 13677   10001040203  Delaware        Kent              5017
# 13678   10001040501  Delaware        Kent              4923
# ...             ...       ...         ...               ...
# 13769   10003013501  Delaware  New Castle              6602
# 13770   10003013503  Delaware  New Castle              7472
# 13771   10003013505  Delaware  New Castle              3147
# 13772   10003013506  Delaware  New Castle              4833
# 13773   10003013604  Delaware  New Castle              4074
#
#        Total_Housing_Units  Median_Family_Income  Units_Without_Vehicle  \
# 13674                 2325                 71188                     39
# 13675                 1849                 54826                    160
# 13676                 4451                 73155                    121
# 13677                 1877                 69273                    146
# 13678                 1910                 57891                    142
# ...                    ...                   ...                    ...
# 13769                 2452                128802                    118
# 13770                 2620                117326                     80
# 13771                 1128                168553                     27
# 13772                 1617                155625                      0
# 13773                 1583                 85231                     44
#
#        Poverty_Rate   Latitude  Longitude                  Car Dealer
# 13674          10.7  39.237284 -75.694741  Carman Chrysler Jeep Dodge
# 13675           8.7  39.290841 -75.637508                 Winner Ford
# 13676           5.3  39.263964 -75.611123                 Winner Ford
# 13677          11.9  39.285868 -75.550836          Martin Dealerships
# 13678          16.9  39.199584 -75.543902                 Winner Ford
# ...             ...        ...        ...                         ...
# 13769           1.4  39.781704 -75.658343          Martin Dealerships
# 13770           3.8  39.781677 -75.693759         Pacifico Ford, Inc.
# 13771           2.1  39.765072 -75.718149            Colonial Hyundai
# 13772           0.6  39.752546 -75.734866            Colonial Hyundai
# 13773           7.4  39.723522 -75.681612            Colonial Hyundai
#
# [100 rows x 11 columns]

# %%
# Python program to convert 
# JSON file to CSV 
  
  
import csv 
  
  
# Opening JSON file and loading the data 
# into the variable data 
with open('dealers_info.json') as json_file: 
    data = json.load(json_file) 
  
car_dealers_info = data['emp_details'] 
  
# now we will open a file for writing 
data_file = open('data_file.csv', 'w') 
  
# create the csv writer object 
csv_writer = csv.writer(data_file) 
  
# Counter variable used for writing  
# headers to the CSV file 
count = 0
  
for emp in employee_data: 
    if count == 0: 
  
        # Writing headers of CSV file 
        header = emp.keys() 
        csv_writer.writerow(header) 
        count += 1
  
    # Writing data of CSV file 
    csv_writer.writerow(emp.values()) 
  
data_file.close()
